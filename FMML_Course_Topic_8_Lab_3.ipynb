# %% [markdown]
# <a href="https://colab.research.google.com/github/SACO14subrahmanyam/FMML_ASSIGINMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-04 04:58:52--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   132MB/s    in 0.5s
#
# 2023-05-04 04:58:53 (132 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 14237   1302.0895v1  Many applications concern sparse signals, for ...  stat
# 3773    1401.1489v1  To answer the existence of optimal swimmer lea...  stat
# 8939   1708.05682v1  Long Short-Term Memory (LSTM) is the primary r...    cs
# 33066  1802.00187v1  Clustering is essential to many tasks in patte...    cs
# 9107    1309.5319v1  The motor theory of speech perception holds th...    cs
# ...             ...                                                ...   ...
# 22424  1606.05889v1  Compressed sensing refers to the recovery of a...  stat
# 4988   1707.05390v1  We present an implementation of a probabilisti...    cs
# 22021   1311.6182v1  Robust tensor recovery plays an instrumental r...  stat
# 35784   1208.1103v1  System identification from the experimental da...    cs
# 3524   1711.01768v3  Many deployed learned models are black boxes: ...  stat
#
#                                                    title  year  \
# 14237          Exact Sparse Recovery with L0 Projections  2013
# 3773   Key point selection and clustering of swimmer ...  2014
# 8939   An Improved Residual LSTM Architecture for Aco...  2017
# 33066  Clustering and Unsupervised Anomaly Detection ...  2018
# 9107   Recognizing Speech in a Novel Accent: The Moto...  2013
# ...                                                  ...   ...
# 22424  Tight Performance Bounds for Compressed Sensin...  2016
# 4988    TensorLog: Deep Learning Meets Probabilistic DBs  2017
# 22021  Robust Low-rank Tensor Recovery: Models and Al...  2013
# 35784  System identification and modeling for interac...  2012
# 3524   Towards Reverse-Engineering Black-Box Neural N...  2017
#
#                                                 keywords
# 14237  [applications, detecting, anomalies, differenc...
# 3773   [existence, learningteaching, strategies, intr...
# 8939   [recurrent, architecture, automatic, recogniti...
# 33066  [clustering, essential, recognition, increasin...
# 9107   [perception, representation, recognize, plausi...
# ...                                                  ...
# 22424  [compressed, dimensional, measurements, minimi...
# 4988   [implementation, probabilistic, tensorlog, dif...
# 22021  [instrumental, robustifying, decompositions, m...
# 35784  [identification, experimental, controller, der...
# 3524   [information, architecture, optimisation, proc...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 14237    [applications, detecting, anomalies, differenc...
# 3773     [existence, learningteaching, strategies, intr...
# 8939     [recurrent, architecture, automatic, recogniti...
# 33066    [clustering, essential, recognition, increasin...
# 9107     [perception, representation, recognize, plausi...
#                                ...
# 21929    [estimation, functions, important, scintigraph...
# 22552    [alternate, resulting, interpreted, alternate,...
# 3787     [recognition, approaches, inherently, difficul...
# 23438    [improving, capturing, different, methodology,...
# 27       [particular, originally, optimization, logarit...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8795 words.
# Out of those 4528 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="528fa95c-0f77-46d2-95bf-1be11ccad291" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("528fa95c-0f77-46d2-95bf-1be11ccad291")) {                    Plotly.newPlot(                        "528fa95c-0f77-46d2-95bf-1be11ccad291",                        [{"x":["significant","procedure","measurement","detecting","typically","recovering","applications","understanding","intuition","interestingly","coordinates","anomalies","consecutive","projections","framework","recovered","measurements","programming","differences","distribution","mainstream","surveillance","optimization","algorithm","comparisons","generated","iterations","regardless","idealized","iteration","orthogonal","sufficient","dimensions","demonstrate","compressed","significantly","baselines","unsupervised","introduces","correlated","knowledge","performed","efficiently","selection","coordination","strategies","clustering","existence","efficient","experiments","architecture","automatic","reduction","recognition","librispeech","recurrent","switchboard","increasing","euclidean","constraint","representations","previously","reconstruction","normalization","separable","normalized","essential","detection","observation","augmented","currently","reframing","linguistic","consideration","computational","recognizing","discussion","implications","listeners","relevance","perception","probabilities","formation","recognize","processing","repertoire","reference","extensions","plausible","representation","understand","hypotheses","regarding","augmentation","surprisingly","regularization","rectified","incorporates","performance","following","techniques","unfortunately","additional","supervised","convolutional","interpretable","equivalent","simulations","algorithms","developed","complexity","interpretability","conditions","extracting","improving","parameters","functionally","determine","therefore","advantage","predictions","stability","consistency","estimators","interactions","available","empirical","estimation","prediction","validation","classical","variables","generally","automatically","quadratic","ingredients","construct","computing","computation","polynomial","prohibitively","differentiation","expensive","usefulness","multilinear","exponentially","quadratically","posterior","evaluation","expanding","inference","applicability","structured","efficiency","monocular","positions","personalization","estimates","dimensional","competing","generating","deformations","synthetic","estimated","opportunities","capturing","distributions","furthermore","achieving","collected","particularly","particular","probabilistic","observing","adaptively","minimizes","consequently","optimality","probability","uncertainty","infeasible","rendering","assumption","calculations","represented","resultant","classifier","predictive","underlying","structure","averaging","graphical","decomposable","formalism","dependence","decomposability","classifiers","collection","indicative","generates"],"y":[252,118,38,72,110,26,433,126,23,17,10,8,14,20,552,6,57,118,54,219,3,35,317,825,41,153,22,19,0,48,17,63,46,539,28,284,67,144,78,28,371,122,157,166,8,100,139,36,439,622,243,189,97,397,2,151,6,103,37,102,242,91,102,30,12,18,72,347,71,36,58,1,61,33,273,46,32,16,4,32,39,53,14,43,275,3,34,40,21,346,44,24,41,22,28,75,7,31,868,82,383,29,110,209,378,33,53,43,598,183,219,25,144,57,99,238,2,67,157,107,76,35,64,11,53,303,159,201,224,45,101,117,76,192,16,4,86,134,146,67,6,4,62,33,3,25,4,44,263,5,200,26,104,153,36,26,3,72,186,15,88,21,142,66,23,44,120,185,70,65,87,277,160,18,24,16,31,26,177,81,14,16,64,3,77,11,156,63,126,325,23,57,4,23,19,1,121,84,3,58],"type":"bar"},{"x":["significant","procedure","measurement","detecting","typically","recovering","applica ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4528,), (4528, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7975

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>a</span> <span style=''>Driving</span> <span style='background-color:rgba(0, 255, 0, 0.37500000000000006);'>Simulator</span> <br/><br/><span style=''>Commaais</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.5151515151515151);'>Artificial</span> <span style='background-color:rgba(0, 255, 0, 0.7168141592920354);'>Intelligence</span> <span style=''>for</span> <span style=''>self</span> <span style=''>driving</span> <span style=''>cars</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>an</span> <span style=''>agent</span> <span style=''>that</span> <span style=''>learns</span> <span style=''>to</span> <span style=''>clone</span> <span style=''>driver</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>behaviors</span> <span style=''>and</span> <span style=''>plans</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>maneuvers</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>simulating</span> <span style=''>future</span> <span style=''>events</span> <span style=''>in</span> <span style=''>the</span> <span style=''>road</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>illustrates</span> <span style=''>one</span> <span style=''>of</span> <span style=''>our</span> <span style=''>research</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>for</span> <span style=''>driving</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simulation</span> <span style=''>One</span> <span style=''>where</span> <span style=''>we</span> <span style=''>learn</span> <span style=''>to</span> <span style=''>simulate</span> <span style=''>Here</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigate</span> <span style='background-color:rgba(255, 0, 0, 0.575);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>autoencoders</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classical</span> <span style=''>and</span> <span style=''>learned</span> <span style=''>cost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarial</span> <span style=''>networks</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>road</span> <span style=''>frames</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>Afterwards</span> <span style=''>we</span> <span style=''>learn</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style=''>model</span> <span style=''>in</span> <span style=''>the</span> <span style=''>embedded</span> <span style=''>space</span> <span style=''>using</span> <span style=''>action</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditioned</span> <span style='background-color:rgba(0, 255, 0, 0.4876847290640394);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>can</span> <span style=''>keep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predicting</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>realistic</span> <span style=''>looking</span> <span style=''>video</span> <span style=''>for</span> <span style=''>several</span> <span style=''>frames</span> <span style=''>despite</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Sequential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style=''>Process</span> <span style=''>Mixtures</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multivariate</span> <span style=''>Skew</span> <span style=''>t</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>for</span> <span style=''>Model</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>of</span> <span style=''>Flow</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Cytometry</span> <span style=''>Data</span> <br/><br/><span style=''>Flow</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cytometry</span> <span style=''>is</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>throughput</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technology</span> <span style=''>used</span> <span style=''>to</span> <span style=''>quantify</span> <span style=''>multiple</span> <span style=''>surface</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intracellular</span> <span style=''>markers</span> <span style=''>at</span> <span style=''>the</span> <span style=''>level</span> <span style=''>of</span> <span style=''>a</span> <span style=''>single</span> <span style=''>cell</span> <span style=''>This</span> <span style=''>enables</span> <span style=''>to</span> <span style=''>identify</span> <span style=''>cell</span> <span style=''>sub</span> <span style=''>types</span> <span style=''>and</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determine</span> <span style=''>their</span> <span style=''>relative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proportions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Improvements</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technology</span> <span style=''>allow</span> <span style=''>to</span> <span style=''>describe</span> <span style=''>millions</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>cells</span> <span style=''>from</span> <span style=''>a</span> <span style=''>blood</span> <span style=''>sample</span> <span style=''>using</span> <span style=''>multiple</span> <span style=''>markers</span> <span style=''>This</span> <span style=''>results</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>datasets</span> <span style=''>whose</span> <span style=''>manual</span> <span style=''>analysis</span> <span style=''>is</span> <span style=''>highly</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consuming</span> <span style=''>and</span> <span style=''>poorly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reproducible</span> <span style=''>While</span> <span style=''>several</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>to</span> <span style=''>perform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>of</span> <span style=''>cell</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>populations</span> <span style=''>most</span> <span style=''>of</span> <span style=''>them</span> <span style=''>treat</span> <span style=''>and</span> <span style=''>analyze</span> <span style=''>each</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independently</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Theory</span> <span style=''>II</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Landscape</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Empirical</span> <span style=''>Risk</span> <span style=''>in</span> <span style=''>Deep</span> <span style=''>Learning</span> <br/><br/><span style=''>Previous</span> <span style='background-color:rgba(255, 0, 0, 0.3278008298755186);'>theoretical</span> <span style=''>work</span> <span style=''>on</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>tend</span> <span style=''>to</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>avoiding</span> <span style=''>saddle</span> <span style=''>points</span> <span style=''>and</span> <span style=''>local</span> <span style=''>minima</span> <span style=''>However</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>is</span> <span style=''>that</span> <span style=''>at</span> <span style=''>least</span> <span style=''>in</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successful</span> <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.6153846153846154);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>(DCNNs)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practitioners</span> <span style=''>can</span> <span style=''>always</span> <span style=''>increase</span> <span style=''>the</span> <span style=''>network</span> <span style=''>size</span> <span style=''>to</span> <span style=''>fit</span> <span style=''>the</span> <span style=''>training</span> <span style=''>data</span> <span style=''>(an</span> <span style=''>extreme</span> <span style=''>example</span> <span style=''>would</span> <span style=''>be</span> <span style=''>1)</span> <span style=''>The</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successful</span> <span style=''>DCNNs</span> <span style=''>such</span> <span style=''>as</span> <span style=''>VGG</span> <span style=''>and</span> <span style=''>ResNets</span> <span style=''>are</span> <span style=''>best</span> <span style=''>used</span> <span style=''>with</span> <span style=''>a</span> <span style=''>degree</span> <span style=''>of</span> <span style=''>overparametrization</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterize</span> <span style=''>with</span> <span style=''>a</span> <span style=''>mix</span> <span style=''>of</span> <span style=''>theory</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>landscape</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style=''>of</span> <span style=''>overparametrized</span> <span style=''>DCNNs</span> <span style=''>We</span> <span style=''>first</span> <span style=''>prove</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5873684210526315);'>regression</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>existence</span> <span style=''>of</span> <span style=''>a</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>for</span> <span style=''>Anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <br/><br/><span style=''>Anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>based</span> <span style=''>on</span> <span style=''>one</span> <span style=''>class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>is</span> <span style=''>broadly</span> <span style=''>used</span> <span style=''>in</span> <span style=''>many</span> <span style=''>applied</span> <span style=''>domains</span> <span style=''>like</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>(eg</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>of</span> <span style=''>whether</span> <span style=''>a</span> <span style=''>patient</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cancerous</span> <span style=''>or</span> <span style=''>healthy</span> <span style=''>from</span> <span style=''>mammography</span> <span style=''>image)</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intrusion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>etc</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Performance</span> <span style=''>of</span> <span style=''>an</span> <span style=''>anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>crucially</span> <span style=''>depends</span> <span style=''>on</span> <span style=''>a</span> <span style=''>kernel</span> <span style=''>used</span> <span style=''>to</span> <span style=''>measure</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>in</span> <span style=''>a</span> <span style=''>feature</span> <span style=''>space</span> <span style=''>The</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>(eg</span> <span style=''>cross</span> <span style=''>validation)</span> <span style=''>for</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>used</span> <span style=''>in</span> <span style=''>two</span> <span style=''>class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>can</span> <span style=''>not</span> <span style=''>be</span> <span style=''>used</span> <span style=''>directly</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>specific</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>a</span> <span style=''>data</span> <span style=''>(absence</span> <span style=''>of</span> <span style=''>a</span> <span style=''>second</span> <span style=''>abnormal</span> <span style=''>class</span> <span style=''>data)</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style=''>several</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>methods</span> <span style=''>from</span> <span style=''>binary</span> <span style=''>class</span> <span style=''>case</span> <span style=''>to</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style=''>one</span> <span style=''>class</span> <span style='backgroun ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.09846043680630147)
# 	architecture (0.08700322234156821)
# 	knowledge (0.13283208020050125)
# 	experimental (0.14035087719298245)
# 	segmentation (0.07841031149301826)
# 	information (0.2538489079842463)
# 	detection (0.12423916935195131)
# 	convolutional (0.13533834586466165)
# 	different (0.27425707124955245)
# 	recognition (0.14214106695309703)
#
# Some Statistics words are:
# 	algorithm (0.3866467364225212)
# 	stochastic (0.13203786746387644)
# 	variables (0.13901345291479822)
# 	theoretical (0.15944195316392626)
# 	statistical (0.15595416043846538)
# 	estimation (0.18086696562032886)
# 	distribution (0.19033383158943698)
# 	inference (0.1998006975585451)
# 	dimensional (0.20378674638764324)
# 	regression (0.1878425510712506)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="803612b6-4347-4252-9f08-8afc9218908a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("803612b6-4347-4252-9f08-8afc9218908a")) {                    Plotly.newPlot(                        "803612b6-4347-4252-9f08-8afc9218908a",                        [{"x":["significant","procedure","measurement","detecting","typically","recovering","applications","understanding","intuition","interestingly","coordinates","anomalies","consecutive","projections","framework","recovered","measurements","programming","differences","distribution","mainstream","surveillance","optimization","algorithm","comparisons","generated","iterations","regardless","idealized","iteration","orthogonal","sufficient","dimensions","demonstrate","compressed","significantly","baselines","unsupervised","introduces","correlated","knowledge","performed","efficiently","selection","coordination","strategies","clustering","existence","efficient","experiments","architecture","automatic","reduction","recognition","librispeech","recurrent","switchboard","increasing","euclidean","constraint","representations","previously","reconstruction","normalization","separable","normalized","essential","detection","observation","augmented","currently","reframing","linguistic","consideration","computational","recognizing","discussion","implications","listeners","relevance","perception","probabilities","formation","recognize","processing","repertoire","reference","extensions","plausible","representation","understand","hypotheses","regarding","augmentation","surprisingly","regularization","rectified","incorporates","performance","following","techniques","unfortunately","additional","supervised","convolutional","interpretable","equivalent","simulations","algorithms","developed","complexity","interpretability","conditions","extracting","improving","parameters","functionally","determine","therefore","advantage","predictions","stability","consistency","estimators","interactions","available","empirical","estimation","prediction","validation","classical","variables","generally","automatically","quadratic","ingredients","construct","computing","computation","polynomial","prohibitively","differentiation","expensive","usefulness","multilinear","exponentially","quadratically","posterior","evaluation","expanding","inference","applicability","structured","efficiency","monocular","positions","personalization","estimates","dimensional","competing","generating","deformations","synthetic","estimated","opportunities","capturing","distributions","furthermore","achieving","collected","particularly","particular","probabilistic","observing","adaptively","minimizes","consequently","optimality","probability","uncertainty","infeasible","rendering","assumption","calculations","represented","resultant","classifier","predictive","underlying","structure","averaging","graphical","decomposable","formalism","dependence","decomposability","classifiers","collection","indicative","generates","scientific","technique","important","identifying","preserves","summaries","sentences","inclusion","extractive","embedding","determining","attention","extraction","dropconnect","theoretic","translates","rationality","transform","multilayer","feedforward","classification","successfully","architectures","considered","theoretically","resources","information","overfitting","scenarios","handwritten","different","mathematically","transmission","benchmark","motivated","competitive","sequential","autoregressive","objective","benchmarks","annealing","variability","maximizing","reconstruct","approximate","independent","generative","stochastic","alternative","variational","approaches","condition","associated","conceptually","successful","auxiliary","amortized" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	idealized
# 	methodologically
# 	homomorphic
# 	supermarket
# 	selectors
# 	misspecified
# 	phenotypes
# 	hypernetworks
# 	hypernetwork
# 	heteroscedastic
# 	unplanned
# 	thermostat
# 	thermostats
# 	integrator
# 	econometric
# 	covariates
# 	causation
# 	periodicity
# 	forecaster
# 	sridharan
# Some words which never appear in Statistics papers:
# 	librispeech
# 	switchboard
# 	listeners
# 	functionally
# 	monocular
# 	extractive
# 	dropconnect
# 	explosive
# 	illumination
# 	hypoelliptic
# 	reachability
# 	graphplan
# 	abstraction
# 	constantly
# 	intravascular
# 	susceptibility
# 	contention
# 	electoral
# 	unannotated
# 	treebanks

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0809045535769304e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7533333333333333
